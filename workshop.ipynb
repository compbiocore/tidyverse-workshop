# %% [markdown]
# # Preamble
#
# Most of this workshop is taken from Hadley's [R for Data Science](https://r4ds.had.co.nz/) book. You can find more examples, explanations and exercises there if you want.
#
# # Package prerequisites
#
# The only package that is required in this workshop is **tidyverse**, which includes the packages **ggplot2**, **dplyr**, **purrr**, and others designed for the process of tidying, transforming, and visualizing data with the tidyverse paradigm.

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.0     ✔ purrr   0.2.5
# ✔ tibble  2.0.1     ✔ dplyr   0.7.8
# ✔ tidyr   0.8.2     ✔ stringr 1.3.1
# ✔ readr   1.3.1     ✔ forcats 0.3.0
# Warning message:
# “package ‘tibble’ was built under R version 3.5.2”── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# If you get an error message “there is no package called ‘tidyverse’” then you need to install tidyverse first. (This is something you should have done before coming to the workshop, but it's ok if you didn't and it won't take long.)

# %%
#install.packages('tidyverse')

# %% [markdown]
# # Importing Data
#
# ## tibble
#
# The core unit of the tidyverse is the tibble, provided in the **tibble** package. tibbles are the same as data frames, but with a few different features
#  * Printing data frame shows only first 10 rows instead of all, and only the columns that fit on screen
#  * Each column reports its type
#  * Also reports dimensions of data frame
#  * Will not allow for partial matching in subsetting
#
# Note that these behaviors only happen in RStudio. In Jupytern notebooks tibbles have the same behaviors as data frames by design.

# %%
mtcars
# Out:
#    mpg  cyl disp  hp  drat wt    qsec  vs am gear carb
# 1  21.0 6   160.0 110 3.90 2.620 16.46 0  1  4    4
# 2  21.0 6   160.0 110 3.90 2.875 17.02 0  1  4    4
# 3  22.8 4   108.0  93 3.85 2.320 18.61 1  1  4    1
# 4  21.4 6   258.0 110 3.08 3.215 19.44 1  0  3    1
# 5  18.7 8   360.0 175 3.15 3.440 17.02 0  0  3    2
# 6  18.1 6   225.0 105 2.76 3.460 20.22 1  0  3    1
# 7  14.3 8   360.0 245 3.21 3.570 15.84 0  0  3    4
# 8  24.4 4   146.7  62 3.69 3.190 20.00 1  0  4    2
# 9  22.8 4   140.8  95 3.92 3.150 22.90 1  0  4    2
# 10 19.2 6   167.6 123 3.92 3.440 18.30 1  0  4    4
# 11 17.8 6   167.6 123 3.92 3.440 18.90 1  0  4    4
# 12 16.4 8   275.8 180 3.07 4.070 17.40 0  0  3    3
# 13 17.3 8   275.8 180 3.07 3.730 17.60 0  0  3    3
# 14 15.2 8   275.8 180 3.07 3.780 18.00 0  0  3    3
# 15 10.4 8   472.0 205 2.93 5.250 17.98 0  0  3    4
# 16 10.4 8   460.0 215 3.00 5.424 17.82 0  0  3    4
# 17 14.7 8   440.0 230 3.23 5.345 17.42 0  0  3    4
# 18 32.4 4    78.7  66 4.08 2.200 19.47 1  1  4    1
# 19 30.4 4    75.7  52 4.93 1.615 18.52 1  1  4    2
# 20 33.9 4    71.1  65 4.22 1.835 19.90 1  1  4    1
# 21 21.5 4   120.1  97 3.70 2.465 20.01 1  0  3    1
# 22 15.5 8   318.0 150 2.76 3.520 16.87 0  0  3    2
# 23 15.2 8   304.0 150 3.15 3.435 17.30 0  0  3    2
# 24 13.3 8   350.0 245 3.73 3.840 15.41 0  0  3    4
# 25 19.2 8   400.0 175 3.08 3.845 17.05 0  0  3    2
# 26 27.3 4    79.0  66 4.08 1.935 18.90 1  1  4    1
# 27 26.0 4   120.3  91 4.43 2.140 16.70 0  1  5    2
# 28 30.4 4    95.1 113 3.77 1.513 16.90 1  1  5    2
# 29 15.8 8   351.0 264 4.22 3.170 14.50 0  1  5    4
# 30 19.7 6   145.0 175 3.62 2.770 15.50 0  1  5    6
# 31 15.0 8   301.0 335 3.54 3.570 14.60 0  1  5    8
# 32 21.4 4   121.0 109 4.11 2.780 18.60 1  1  4    2

# %%
#as_tibble(mtcars)
as_tibble(head(mtcars))
# Out:
#   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# 1 21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# 2 21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# 3 22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# 4 21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# 5 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2
# 6 18.1 6   225  105 2.76 3.460 20.22 1  0  3    1

# %% [markdown]
# ## readr
#
# The package **readr** provides options for importing data that has already been set up as tables, such as csvs:
#  * `read_csv()` is for comma-delimited files
#  * `read_csv2()` is for semicolon-delimited files
#  * `read_tsv()` is for tab-delimited files
#  * `read_delim()` is for any other delimiters
#  * `read_fwf()` is for fixed width files
#  * `read_table()` is for fixed width files with columns separated by white space
#
# If you are used to using `read.csv`, `read.table` or other functions from **utils**, these are almost exactly the same except that they import data as tibbles instead of data frames. They are also about 10x faster, provide progress bars when loading larger files, and provide typing for columns.
#
# If your file is massive and you *really* need something as fast as possible, look into the **data.table** package (or consider writing your core functions in C++ and using the **Rcpp** package). Data tables don't fit exactly into the tidyverse but it is not too much more of a learning curve.

# %%
mtcars <- read_csv(readr_example("mtcars.csv"))
# Out:
# Parsed with column specification:
# cols(
#   mpg = col_double(),
#   cyl = col_double(),
#   disp = col_double(),
#   hp = col_double(),
#   drat = col_double(),
#   wt = col_double(),
#   qsec = col_double(),
#   vs = col_double(),
#   am = col_double(),
#   gear = col_double(),
#   carb = col_double()
# )

# %% [markdown]
# These functions have other optional arguments that can be helpful as well.
#
#  * `delim`: in `read_delim()` denotes what delimiter to use
#  * `col_types`: if you know what column types you want your tibble to have, specify it here. Can be useful because often data gets parsed as `factor` or `character` when you may want it to be `character` or `numeric`.
#  * `skip`: how many lines to skip. Default is 0. Useful for when the file you're reading in has comments at the beginning, such as in SAM files.
#
# We won't go through the other arguments, but you can view them in the help for the functions.

# %%
?read_csv

# %% [markdown]
# ## Exercises
#
# 1. Read in the file `exercises/import1.csv` as a tibble with 3 columns with the appropriate function.
# 2. Suppose we are trying to read in the following line into 3 columns: x, y\n1, and 'a,b'.
# ```
# "x,y\n1,'a,b'"
# ```
# What arguments do you need to specify for `read_csv()` to do so properly?
# 3. What is wrong with each of the following inline CSV files?
# ```{r}
# read_csv("a,b\n1,2,3\n4,5,6")
# read_csv("a,b,c\n1,2\n1,2,3,4")
# read_csv("a,b\n\"1")
# read_csv("a,b\n1,2\na,b")
# read_csv("a;b\n1;3")
# ```
#
# ## Solutions

# %%
challenge <- read_csv(readr_example("challenge.csv"))
problems(challenge)
# Out:
# Parsed with column specification:
# cols(
#   x = col_double(),
#   y = col_logical()
# )
# Warning message:
# “1000 parsing failures.
#  row col           expected     actual                                                                                         file
# 1001   y 1/0/T/F/TRUE/FALSE 2015-01-16 '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 1002   y 1/0/T/F/TRUE/FALSE 2018-05-18 '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 1003   y 1/0/T/F/TRUE/FALSE 2015-09-05 '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 1004   y 1/0/T/F/TRUE/FALSE 2012-11-28 '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 1005   y 1/0/T/F/TRUE/FALSE 2020-01-13 '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# .... ... .................. .......... ............................................................................................
# See problems(...) for more details.
# ”
#      row  col expected           actual
# 1    1001 y   1/0/T/F/TRUE/FALSE 2015-01-16
# 2    1002 y   1/0/T/F/TRUE/FALSE 2018-05-18
# 3    1003 y   1/0/T/F/TRUE/FALSE 2015-09-05
# 4    1004 y   1/0/T/F/TRUE/FALSE 2012-11-28
# 5    1005 y   1/0/T/F/TRUE/FALSE 2020-01-13
# 6    1006 y   1/0/T/F/TRUE/FALSE 2016-04-17
# 7    1007 y   1/0/T/F/TRUE/FALSE 2011-05-14
# 8    1008 y   1/0/T/F/TRUE/FALSE 2020-07-18
# 9    1009 y   1/0/T/F/TRUE/FALSE 2011-04-30
# 10   1010 y   1/0/T/F/TRUE/FALSE 2010-05-11
# 11   1011 y   1/0/T/F/TRUE/FALSE 2014-11-02
# 12   1012 y   1/0/T/F/TRUE/FALSE 2014-06-23
# 13   1013 y   1/0/T/F/TRUE/FALSE 2017-05-31
# 14   1014 y   1/0/T/F/TRUE/FALSE 2017-11-18
# 15   1015 y   1/0/T/F/TRUE/FALSE 2013-04-20
# 16   1016 y   1/0/T/F/TRUE/FALSE 2010-12-11
# 17   1017 y   1/0/T/F/TRUE/FALSE 2022-10-10
# 18   1018 y   1/0/T/F/TRUE/FALSE 2010-11-11
# 19   1019 y   1/0/T/F/TRUE/FALSE 2015-03-22
# 20   1020 y   1/0/T/F/TRUE/FALSE 2013-12-25
# 21   1021 y   1/0/T/F/TRUE/FALSE 2011-02-27
# 22   1022 y   1/0/T/F/TRUE/FALSE 2015-12-14
# 23   1023 y   1/0/T/F/TRUE/FALSE 2021-02-10
# 24   1024 y   1/0/T/F/TRUE/FALSE 2012-11-28
# 25   1025 y   1/0/T/F/TRUE/FALSE 2020-04-04
# 26   1026 y   1/0/T/F/TRUE/FALSE 2021-04-08
# 27   1027 y   1/0/T/F/TRUE/FALSE 2022-03-13
# 28   1028 y   1/0/T/F/TRUE/FALSE 2010-03-28
# 29   1029 y   1/0/T/F/TRUE/FALSE 2023-01-04
# 30   1030 y   1/0/T/F/TRUE/FALSE 2012-04-02
# ⋮    ⋮    ⋮   ⋮                  ⋮
# 971  1971 y   1/0/T/F/TRUE/FALSE 2020-06-10
# 972  1972 y   1/0/T/F/TRUE/FALSE 2013-11-08
# 973  1973 y   1/0/T/F/TRUE/FALSE 2017-07-12
# 974  1974 y   1/0/T/F/TRUE/FALSE 2016-08-12
# 975  1975 y   1/0/T/F/TRUE/FALSE 2022-05-12
# 976  1976 y   1/0/T/F/TRUE/FALSE 2020-08-11
# 977  1977 y   1/0/T/F/TRUE/FALSE 2011-10-26
# 978  1978 y   1/0/T/F/TRUE/FALSE 2015-12-09
# 979  1979 y   1/0/T/F/TRUE/FALSE 2012-09-27
# 980  1980 y   1/0/T/F/TRUE/FALSE 2013-02-04
# 981  1981 y   1/0/T/F/TRUE/FALSE 2010-11-29
# 982  1982 y   1/0/T/F/TRUE/FALSE 2013-10-16
# 983  1983 y   1/0/T/F/TRUE/FALSE 2015-04-26
# 984  1984 y   1/0/T/F/TRUE/FALSE 2011-04-12
# 985  1985 y   1/0/T/F/TRUE/FALSE 2017-01-30
# 986  1986 y   1/0/T/F/TRUE/FALSE 2014-06-08
# 987  1987 y   1/0/T/F/TRUE/FALSE 2016-10-19
# 988  1988 y   1/0/T/F/TRUE/FALSE 2023-09-01
# 989  1989 y   1/0/T/F/TRUE/FALSE 2010-01-09
# 990  1990 y   1/0/T/F/TRUE/FALSE 2020-01-11
# 991  1991 y   1/0/T/F/TRUE/FALSE 2016-12-16
# 992  1992 y   1/0/T/F/TRUE/FALSE 2010-01-03
# 993  1993 y   1/0/T/F/TRUE/FALSE 2016-04-23
# 994  1994 y   1/0/T/F/TRUE/FALSE 2016-08-10
# 995  1995 y   1/0/T/F/TRUE/FALSE 2019-11-21
# 996  1996 y   1/0/T/F/TRUE/FALSE 2018-03-29
# 997  1997 y   1/0/T/F/TRUE/FALSE 2014-08-04
# 998  1998 y   1/0/T/F/TRUE/FALSE 2015-08-16
# 999  1999 y   1/0/T/F/TRUE/FALSE 2020-02-04
# 1000 2000 y   1/0/T/F/TRUE/FALSE 2019-01-06
#      file
# 1    '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 2    '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 3    '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 4    '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 5    '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 6    '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 7    '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 8    '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 9    '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 10   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 11   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 12   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 13   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 14   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 15   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 16   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 17   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 18   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 19   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 20   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 21   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 22   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 23   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 24   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 25   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 26   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 27   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 28   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 29   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 30   '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# ⋮    ⋮
# 971  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 972  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 973  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 974  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 975  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 976  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 977  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 978  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 979  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 980  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 981  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 982  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 983  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 984  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 985  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 986  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 987  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 988  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 989  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 990  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 991  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 992  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 993  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 994  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 995  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 996  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 997  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 998  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 999  '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'
# 1000 '/Library/Frameworks/R.framework/Versions/3.5/Resources/library/readr/extdata/challenge.csv'

# %% [markdown]
# # Tidying Data
#
# Consider the following tables:

# %%
table1 <- data.frame(treatmenta=c(NA,16,3),treatmentb=c(2,11,1))
rownames(table1) <- c("John Smith", "Jane Doe", "Mary Johnson")
table1
# Out:
#              treatmenta treatmentb
# John Smith   NA          2
# Jane Doe     16         11
# Mary Johnson  3          1

# %%
table2 <- data.frame(patient=c("John Smith","John Smith","Jane Doe","John Doe","Mary Johnson","Mary Johnson"),
                     treatment=c("a","b","a","b","a","b"),
                    result=c(NA,2,16,11,3,1))
table2
# Out:
#   patient      treatment result
# 1 John Smith   a         NA
# 2 John Smith   b          2
# 3 Jane Doe     a         16
# 4 John Doe     b         11
# 5 Mary Johnson a          3
# 6 Mary Johnson b          1

# %%
table3 <- data.frame(patient=c("John Smith",))

# %% [markdown]
# ## Gathering
# ## Spreading
# ## Separating
# ## Uniting

# %% [markdown]
# # Transforming Data
#
# ## Filter rows with `filter()`
#
# ## Arrange rows with `arrange()`
#
# ## Select columns with `select()`
#
# ## Add new variables with `mutate()`
#
# ## Grouped summaries wit

# %% [markdown]
# # Visualizing Data
#
# The ultimate tool of

# %% [markdown]
# # Publication Quality Graphs

# %% [markdown]
# # Some other useful visualization packages
#
# We don't have time in this workshop to get in depth to other workshops, but here are some more useful visualization packages that may be helpful for your research.
#
# ## ggtree for phylogenetics
#
# Resources and associated packages:
#  * [Data Integration, Manipulation and Visualization of Phylogenetic Trees](https://yulab-smu.github.io/treedata-book/index.html)
#  * [treeio](https://bioconductor.org/packages/release/bioc/html/treeio.html)
#  * [tidytree](https://cran.r-project.org/web/packages/tidytree/index.html)

# %%
sessionInfo()
# Out:
# R version 3.5.1 (2018-07-02)
# Platform: x86_64-apple-darwin15.6.0 (64-bit)
# Running under: macOS  10.14.3
#
# Matrix products: default
# BLAS: /Library/Frameworks/R.framework/Versions/3.5/Resources/lib/libRblas.0.dylib
# LAPACK: /Library/Frameworks/R.framework/Versions/3.5/Resources/lib/libRlapack.dylib
#
# locale:
# [1] en_US.UTF-8/en_US.UTF-8/en_US.UTF-8/C/en_US.UTF-8/en_US.UTF-8
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] forcats_0.3.0   stringr_1.3.1   dplyr_0.7.8     purrr_0.2.5
# [5] readr_1.3.1     tidyr_0.8.2     tibble_2.0.1    ggplot2_3.1.0
# [9] tidyverse_1.2.1
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.0       cellranger_1.1.0 plyr_1.8.4       pillar_1.3.1
#  [5] compiler_3.5.1   bindr_0.1.1      base64enc_0.1-3  tools_3.5.1
#  [9] digest_0.6.18    uuid_0.1-2       lubridate_1.7.4  jsonlite_1.6
# [13] evaluate_0.12    nlme_3.1-137     gtable_0.2.0     lattice_0.20-38
# [17] pkgconfig_2.0.2  rlang_0.3.1      cli_1.0.1        rstudioapi_0.9.0
# [21] IRdisplay_0.7.0  IRkernel_0.8.15  haven_2.0.0      bindrcpp_0.2.2
# [25] withr_2.1.2      xml2_1.2.0       httr_1.4.0       repr_0.19.2
# [29] hms_0.4.2        generics_0.0.2   grid_3.5.1       tidyselect_0.2.5
# [33] glue_1.3.0.9000  R6_2.3.0         readxl_1.2.0     pbdZMQ_0.3-3
# [37] modelr_0.1.2     magrittr_1.5     backports_1.1.3  scales_1.0.0
# [41] htmltools_0.3.6  rvest_0.3.2      assertthat_0.2.0 colorspace_1.4-0
# [45] stringi_1.2.4    lazyeval_0.2.1   munsell_0.5.0    broom_0.5.1
# [49] crayon_1.3.4
